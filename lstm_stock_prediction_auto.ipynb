# %% [markdown]
# # 🔄 Prediksi Harga Saham LSTM (Auto Version)
# Notebook ini otomatis:
# 1. Masuk ke folder repo
# 2. Jalankan script prediksi
# 3. Tampilkan hasil prediksi dalam grafik

# %%
# Pindah ke folder project
# %cd lstm-stock-prediction

# %%
# Jalankan prediksi dan simpan hasil
# !python predict_lengkap.py

# %%
# Cek apakah file hasil prediksi tersedia
# !ls -lh prediksi_7hari.csv

# %%
# Visualisasi hasil prediksi
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('prediksi_7hari.csv')
df['Tanggal'] = pd.to_datetime(df['Tanggal'])
df.set_index('Tanggal', inplace=True)
df.plot(figsize=(10,5), title='📈 Prediksi Harga Saham 7 Hari ke Depan')
plt.grid()
plt.show()
