# %% [markdown]
# # Prediksi Harga Saham dengan LSTM (Google Colab)
# Notebook ini menghubungkan langsung dengan GitHub kamu dan menjalankan prediksi berdasarkan model LSTM yang telah dilatih.

# %%
# Clone repositori GitHub kamu
# !git clone https://github.com/mamuyy/lstm-stock-prediction.git
# %cd lstm-stock-prediction

# %%
# Install dependensi jika perlu
# !pip install pandas numpy matplotlib tensorflow scikit-learn

# %%
# Jalankan script prediksi
# !python predict_lengkap.py

# %%
# (Opsional) Visualisasi hasil jika ada output CSV atau array prediksi
import pandas as pd
import matplotlib.pyplot as plt

# Misalnya hasil prediksi disimpan di 'prediksi_7hari.csv'
try:
    df = pd.read_csv('prediksi_7hari.csv')
    df['Tanggal'] = pd.to_datetime(df['Tanggal'])
    df.set_index('Tanggal', inplace=True)
    df.plot(figsize=(10,5), title='Prediksi Harga Saham 7 Hari ke Depan')
    plt.grid()
    plt.show()
except Exception as e:
    print("Belum ada file prediksi_7hari.csv. Cek script predict_lengkap.py")
